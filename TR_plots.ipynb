# %% [markdown]
# # This note book is used for plotting graphs of TR/DTR test results.

# %% [markdown]
# * load safedigital package
# * change current directory

# %%
from safedigital import temperature as TR

# %%
import os
os.chdir('../')
curDirectory = os.getcwd()
print(curDirectory)
# Out:
# c:\Users\cnbofan1\ABB\Safe Digital in CN - Documents - Documents\06_Test and Analytics

# %% [markdown]
# ## Plot of 20211014
# the temperature is not balanced

# %%
# file path for 20211014
file_path = curDirectory + \
    '\\20211014_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\20211014_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211014_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\2021-10-14_config.json'
fig_path = curDirectory + '\\20211014_TR SR40.5kV cable skin horz 630A\\3_Graphs'

# phase A
col_list = ["t_C1_phA_snsr_skin_horz_top",
            "t_C1_phA_cplr_skin_horz_top",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', '-', '--']
line_color = ['r', 'r', 'g', 'g']


case1014 = TR.TempRiseExperiment(file_path, config_path)
case1014.find_balance_index(list(range(18, 48)))
case1014.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')
# Out:
# Temperature is not balanced.

# %% [markdown]
# ## Plot of 20211015

# %%
file_path = curDirectory + \
    '\\20211015_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\20211015_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211015_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\2021-10-15_config.json'
fig_path = curDirectory + '\\20211015_TR SR40.5kV cable skin horz 630A\\3_Graphs'

col_list = ["t_C1_phA_snsr_skin_horz_top",
            "t_C1_phA_cplr_skin_horz_top",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', '-', '--']
line_color = ['r', 'r', 'g', 'g']


case1014 = TR.TempRiseExperiment(file_path, config_path)
case1014.find_balance_index(list(range(18, 48)))
case1014.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25828/672128428.py in <module>
#      14
#      15
# ---> 16 case1014 = TR.TempRiseExperiment(file_path, config_path)
#      17 case1014.find_balance_index(list(range(18, 48)))
#      18 case1014.t_plot(col_name_list=col_list,
#
# c:\Users\cnbofan1\ABB\Safe Digital in CN - Documents - Documents\06_Test and Analytics\01_Code\safedigital\temperature.py in __init__(self, clean_data_file, config_file)
#      42         """
#      43         # load clean data and config file
# ---> 44         self.data = pd.read_csv(clean_data_file)
#      45         with open(config_file, 'r') as f:
#      46             self.config = json.load(f)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
# ...

# %% [markdown]
# ## Plot of 20211019

# %%
file_path = curDirectory + \
    '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\20211019_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\2021-10-19_config.json'
fig_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\3_Graphs'

col_list = ["t_C1_phA_snsr_skin_vert_out",
            "t_C1_phA_cplr_skin_vert_upper",
            "t_C1_phA_cplr_skin_vert_lower",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', ':', '-', '--']
line_color = ['r', 'r', 'r', 'g', 'g']


case1019 = TR.TempRiseExperiment(file_path, config_path)
case1019.find_balance_index(list(range(18, 52)))
case1019.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25828/382481158.py in <module>
#      15
#      16
# ---> 17 case1019 = TR.TempRiseExperiment(file_path, config_path)
#      18 case1019.find_balance_index(list(range(18, 52)))
#      19 case1019.t_plot(col_name_list=col_list,
#
# c:\Users\cnbofan1\ABB\Safe Digital in CN - Documents - Documents\06_Test and Analytics\01_Code\safedigital\temperature.py in __init__(self, clean_data_file, config_file)
#      44         self.data = pd.read_csv(clean_data_file)
#      45         with open(config_file, 'r') as f:
# ---> 46             self.config = json.load(f)
#      47
#      48         # rename the columns of data(DataFrame) by using config.json file
#
# ...

# %% [markdown]
# ## Plot of 20211025

# %%
file_path = curDirectory + \
    '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\20211019_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\2021-10-19_config.json'
fig_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\3_Graphs'

# %%
col_list = ["t_C1_phA_snsr_skin_vert_out",
            "t_C1_phA_cplr_skin_vert_upper",
            "t_C1_phA_cplr_skin_vert_lower",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', ':', '-', '--']
line_color = ['r', 'r', 'r', 'g', 'b']


case1019 = TR.TempRiseExperiment(file_path, config_path)
case1019.find_balance_index(list(range(18, 52)))
case1019.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25828/1687620939.py in <module>
#      16
#      17
# ---> 18 case1019 = TR.TempRiseExperiment(file_path, config_path)
#      19 case1019.find_balance_index(list(range(18, 52)))
#      20 case1019.t_plot(col_name_list=col_list,
#
# c:\Users\cnbofan1\ABB\Safe Digital in CN - Documents - Documents\06_Test and Analytics\01_Code\safedigital\temperature.py in __init__(self, clean_data_file, config_file)
#      44         self.data = pd.read_csv(clean_data_file)
#      45         with open(config_file, 'r') as f:
# ---> 46             self.config = json.load(f)
#      47
#      48         # rename the columns of data(DataFrame) by using config.json file
#
# ...

# %% [markdown]
# ## Plot of 20211101
# * point 1
# * point 2

# %%
file_path = curDirectory + \
    '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\20211101_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\2021-11-01_config.json'
fig_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\3_Graphs'

line_style = ['-', '--', ':', '-', '--']
line_color = ['r', 'r', 'r', 'g', 'g']

case1014 = TR.TempRiseExperiment(file_path, config_path)
case1014.find_balance_index(list(range(18, 52)))

# %%
col_list = ["t_C1_phA_snsr_skin_vert_out",
            "t_C1_phA_skin_vert_out_upper",
            "t_C1_phA_skin_vert_out_low",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_bushing"]

case1014.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 300A')
# Out:
# Temperature balance time is 2021-11-01 14:14:10.

# %% [markdown]
# ## Plot of 20211104

# %%
file_path = curDirectory + \
    '\\20211104_DTR&TR_3in1_SR12kV 300A\\1_Data formatted\\20211104_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211104_DTR&TR_3in1_SR12kV 300A\\1_Data formatted\\2021-11-04_config.json'
fig_path = curDirectory + '\\20211104_DTR&TR_3in1_SR12kV 300A\\3_Graphs'

line_style = ['-', '--', ':', '-', '--', ':']
line_color = ['r', 'r', 'r', 'g', 'g', 'g']

case = TR.TempRiseExperiment(file_path, config_path)
case.find_balance_index(list(range(18, 52)))

# %%
col_list = ["t_C1_phA_snsr_bushing",
            "t_C1_phB_snsr_bushing",
            "t_C1_phC_snsr_bushing",
            "t_V3_phA_snsr_skin_vert_out",
            "t_V3_phB_snsr_skin_vert_out",
            "t_V3_phC_snsr_skin_vert_out"]

for i in col_list:
    case.data[i] = case.np_move_avg(case.data[i], 20, mode='valid')

case.t_plot(col_name_list=col_list,
            fig_path=fig_path,
            # line_style=line_style,
            line_color=line_color,
            title='3in1 sensor test @ 300A')
# Out:
# Temperature balance time is 2021-11-04 16:05:50.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25828/1550503828.py in <module>
#      20
#      21 for i in col_list:
# ---> 22     case.data[i] = case.np_move_avg(case.data[i], 20, mode='valid')
#      23
#      24 case.t_plot(col_name_list=col_list,
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
# ...

# %% [markdown]
# ## Calculate DTR time constant T of 20211029

# %%
file_path = curDirectory + \
    '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\20211029_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\2021-10-29_config.json'
fig_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\3_Graphs'

case1029 = TR.TempRiseExperiment(file_path, config_path)
case1029.find_balance_index(list(range(18, 52)))
case1029.cal_dynamic_time_const('t_C1_phA_snsr_bushing')
case1029.cal_dynamic_time_const('t_C1_phB_snsr_bushing')
case1029.cal_dynamic_time_const('t_C1_phC_snsr_bushing')
# Out:
# Temperature balance time is 2021-10-29 13:26:10.
# time constant T of t_C1_phA_snsr_bushing is 5555.1335678170235
# time constant T of t_C1_phB_snsr_bushing is 4778.606060671214
# time constant T of t_C1_phC_snsr_bushing is 5151.734422320041
# 5151.734422320041

# %% [markdown]
# ## Calculate DTR time constant T of 20211101

# %%
file_path = curDirectory + \
    '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\20211101_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\2021-11-01_config.json'
fig_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\3_Graphs'

case1101 = TR.TempRiseExperiment(file_path, config_path)
case1101.find_balance_index(list(range(18, 52)))
case1101.cal_dynamic_time_const('t_C1_phA_snsr_bushing')
case1101.cal_dynamic_time_const('t_C1_phB_snsr_bushing')
case1101.cal_dynamic_time_const('t_C1_phC_snsr_bushing')
# Out:
# Temperature balance time is 2021-11-01 14:14:10.
# time constant T of t_C1_phA_snsr_bushing is 6526.488150055641
# time constant T of t_C1_phB_snsr_bushing is 6006.416619924295
# time constant T of t_C1_phC_snsr_bushing is 6463.517374496997
# 6463.517374496997

# %% [markdown]
# ## Calculate DTR time constant T of 20211105

# %%
file_path = curDirectory + \
    '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\20211105_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\2021-11-05_config.json'
fig_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\3_Graphs'

case1105 = TR.TempRiseExperiment(file_path, config_path)
case1105.find_balance_index(list(range(18, 52)))
case1105.cal_dynamic_time_const('t_C1_phA_snsr_bushing')
case1105.cal_dynamic_time_const('t_C1_phB_snsr_bushing')
case1105.cal_dynamic_time_const('t_C1_phC_snsr_bushing')
# Out:
# Temperature balance time is 2021-11-05 18:27:00.
# time constant T of t_C1_phA_snsr_bushing is 6684.800557548545
# time constant T of t_C1_phB_snsr_bushing is 6241.062125565401
# time constant T of t_C1_phC_snsr_bushing is 6522.707606331989
# 6522.707606331989

# %% [markdown]
# ## Calculate DTR conversion constant a of 20211029,20211101,20211105

# %%
tr_100A_phA = case1029.data.loc[case1029.bal_idx,
                                't_C1_phA_snsr_bushing'] - case1029.t_oil.iloc[case1029.bal_idx]
tr_300A_phA = case1101.data.loc[case1101.bal_idx,
                                't_C1_phA_snsr_bushing'] - case1101.t_oil.iloc[case1101.bal_idx]
tr_630A_phA = case1105.data.loc[case1105.bal_idx,
                                't_C1_phA_snsr_bushing'] - case1105.t_oil.iloc[case1105.bal_idx]

conver_const_phA = TR.TempRiseExperiment.cal_dynamic_conver_const([100, 300, 630],
                                                                  [tr_100A_phA, tr_300A_phA, tr_630A_phA])

tr_100A_phB = case1029.data.loc[case1029.bal_idx,
                                't_C1_phB_snsr_bushing'] - case1029.t_oil.iloc[case1029.bal_idx]
tr_300A_phB = case1101.data.loc[case1101.bal_idx,
                                't_C1_phB_snsr_bushing'] - case1101.t_oil.iloc[case1101.bal_idx]
tr_630A_phB = case1105.data.loc[case1105.bal_idx,
                                't_C1_phB_snsr_bushing'] - case1105.t_oil.iloc[case1105.bal_idx]

conver_const_phB = TR.TempRiseExperiment.cal_dynamic_conver_const([100, 300, 630],
                                                                  [tr_100A_phB, tr_300A_phB, tr_630A_phB])

tr_100A_phC = case1029.data.loc[case1029.bal_idx,
                                't_C1_phC_snsr_bushing'] - case1029.t_oil.iloc[case1029.bal_idx]
tr_300A_phC = case1101.data.loc[case1101.bal_idx,
                                't_C1_phC_snsr_bushing'] - case1101.t_oil.iloc[case1101.bal_idx]
tr_630A_phC = case1105.data.loc[case1105.bal_idx,
                                't_C1_phC_snsr_bushing'] - case1105.t_oil.iloc[case1105.bal_idx]

conver_const_phC = TR.TempRiseExperiment.cal_dynamic_conver_const([100, 300, 630],
                                                                  [tr_100A_phC, tr_300A_phC, tr_630A_phC])
# Out:
# conversion constant a is 1.6467252722375585
# conversion constant a is 1.6569187751204197
# conversion constant a is 1.640204605474232

# %% [markdown]
# ## Plot DTR algorithm performance of 20211106
# ### Test started at 8:46:00 AM

# %%
file_path = curDirectory + \
    '\\20211106_DTR&TR_SR12kV Current Variant\\1_Data formatted\\20211106_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211106_DTR&TR_SR12kV Current Variant\\1_Data formatted\\2021-11-06_config.json'
fig_path = curDirectory + '\\20211106_DTR&TR_SR12kV Current Variant\\3_Graphs'
case1106 = TR.TempRiseExperiment(file_path, config_path)
# build current variant curve
cur_list = [100] * 360 + [300] * 360 + [500] * 360 + [630] * 360 + [100] * 360
# plot DTR algorithm performance
time_const = 6000
conver_const = 1.65
const = 60
tr_rated = (case1105.data.loc[case1105.bal_idx, 't_C1_phA_snsr_bushing'] -
            case1105.data.loc[case1105.bal_idx, 't_oil_bottle_1'])
print('tr_rated is', tr_rated)
case1106.t_dtr_plot('t_C1_phA_snsr_bushing',
                    cur_list,
                    time_const,
                    conver_const,
                    tr_rated,
                    const,
                    title='phA DTR performance 20211106 T = {} a = {}'.format(time_const,conver_const))

time_const = 5500
conver_const = 1.66
const = 40
tr_rated = (case1105.data.loc[case1105.bal_idx, 't_C1_phB_snsr_bushing'] -
            case1105.data.loc[case1105.bal_idx, 't_oil_bottle_1'])
print('tr_rated is', tr_rated)
case1106.t_dtr_plot('t_C1_phB_snsr_bushing',
                    cur_list,
                    time_const,
                    conver_const,
                    tr_rated,
                    const,
                    title='phB DTR performance 20211106 T = {} a = {}'.format(time_const,conver_const))

time_const = 6000
conver_const = 1.64
const = 50
tr_rated = (case1105.data.loc[case1105.bal_idx, 't_C1_phC_snsr_bushing'] -
            case1105.data.loc[case1105.bal_idx, 't_oil_bottle_1'])
print('tr_rated is', tr_rated)
case1106.t_dtr_plot('t_C1_phC_snsr_bushing',
                    cur_list,
                    time_const,
                    conver_const,
                    tr_rated,
                    const,
                    title='phC DTR performance 20211106 T = {} a = {}'.format(time_const,conver_const))
# Out:
# tr_rated is 32.6
# tr_rated is 36.6
# tr_rated is 35.4

# %% [markdown]
# ## Plot DTR algorithm performance of 20211107
# ### Test started at 11:01:28 AM

# %%
file_path = curDirectory + \
    '\\20211107_DTR&TR_SR12kV Current Variant\\1_Data formatted\\20211107_data_clean_10s.csv'
config_path = curDirectory + \
    '\\20211107_DTR&TR_SR12kV Current Variant\\1_Data formatted\\2021-11-07_config.json'
fig_path = curDirectory + '\\20211107_DTR&TR_SR12kV Current Variant\\3_Graphs'
case1107 = TR.TempRiseExperiment(file_path, config_path)
# # build current variant curve
cur_list = ([100] * 180 + [300] * 270 + [500] * 90 + [630] * 180 +
            [430] * 270 + [200] * 90 + [100] * 180 + [300] * 270 +
            [500] * 90 + [630] * 180 + [400] * 270 + [200] * 90)
# plot DTR algorithm performance of phA
time_const_phA = 6000
conver_const_phA = 1.65
const_phA = 60
tr_rated_phA = (case1105.data.loc[case1105.bal_idx, 't_C1_phA_snsr_bushing'] -
                case1105.data.loc[case1105.bal_idx, 't_oil_bottle_1'])
# tr_rated_phA = tr_rated_phA * 1.0
print('tr_rated_phA is', tr_rated_phA)
case1107.t_dtr_plot('t_C1_phA_snsr_bushing',
                    cur_list,
                    time_const,
                    conver_const,
                    tr_rated_phA,
                    const,
					title='phA DTR performance 20211107 T = {} a = {}'.format(time_const_phA,conver_const_phA))

# plot DTR algorithm performance
time_const_phB = 5500
conver_const_phB = 1.66
const_phB = 40
tr_rated_phB = (case1105.data.loc[case1105.bal_idx, 't_C1_phB_snsr_bushing'] -
                case1105.data.loc[case1105.bal_idx, 't_oil_bottle_1'])
# tr_rated_phB = tr_rated_phB * 1.0
print('tr_rated_phB is', tr_rated_phB)
case1107.t_dtr_plot('t_C1_phB_snsr_bushing',
                    cur_list,
                    time_const_phB,
                    conver_const_phB,
                    tr_rated_phB,
                    const,
					title='phB DTR performance 20211106 T = {} a = {}'.format(time_const_phB,conver_const_phB))

# plot DTR algorithm performance of phC
time_const_phC = 6000
conver_const_phC = 1.64
const_phC = 50
tr_rated_phC = (case1105.data.loc[case1105.bal_idx, 't_C1_phC_snsr_bushing'] -
                case1105.data.loc[case1105.bal_idx, 't_oil_bottle_1'])
# tr_rated_phC = tr_rated_phC * 1.0
print('tr_rated_phC is', tr_rated_phC)
case1107.t_dtr_plot('t_C1_phC_snsr_bushing',
                    cur_list,
                    time_const_phC,
                    conver_const_phC,
                    tr_rated_phC,
                    const_phC,
					title='phC DTR performance 20211107 T = {} a = {}'.format(time_const_phC,conver_const_phC))
# Out:
# tr_rated_phA is 32.6
# tr_rated_phB is 36.6
# tr_rated_phC is 35.4
