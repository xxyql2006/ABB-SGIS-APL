# %% [markdown]
# # This note book is used for plotting graphs of TR/DTR test results.

# %% [markdown]
# * load safedigital package
# * change current directory

# %%
from safedigital import temperature as TR

# %%
import os
os.chdir('../')
curDirectory = os.getcwd()
print(curDirectory)
# Out:
# c:\Users\cnbofan1\ABB\Safe Digital in CN - Documents - Documents\06_Test and Analytics

# %% [markdown]
# ## Plot of 20211014
# the temperature is not balanced

# %%
# file path for 20211014
file_path = curDirectory + '\\20211014_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\20211014_data_clean_10s.csv'
config_path = curDirectory + '\\20211014_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\2021-10-14_config.json'
fig_path = curDirectory + '\\20211014_TR SR40.5kV cable skin horz 630A\\3_Graphs'

# phase A
col_list = ["t_C1_phA_snsr_skin_horz_top",
            "t_C1_phA_cplr_skin_horz_top",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', '-', '--']
line_color = ['r', 'r', 'g', 'g']


case1014 = TR.TempRiseExperiment(file_path, config_path)
case1014.find_balance_index(list(range(18, 48)))
case1014.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')

# %% [markdown]
# ## Plot of 20211015

# %%
file_path = curDirectory + '\\20211015_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\20211015_data_clean_10s.csv'
config_path = curDirectory + '\\20211015_TR SR40.5kV cable skin horz 630A\\1_Data formatted\\2021-10-15_config.json'
fig_path = curDirectory + '\\20211015_TR SR40.5kV cable skin horz 630A\\3_Graphs'

col_list = ["t_C1_phA_snsr_skin_horz_top",
            "t_C1_phA_cplr_skin_horz_top",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', '-', '--']
line_color = ['r', 'r', 'g', 'g']


case1014 = TR.TempRiseExperiment(file_path, config_path)
case1014.find_balance_index(list(range(18, 48)))
case1014.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')

# %% [markdown]
# ## Plot of 20211019

# %%
file_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\20211019_data_clean_10s.csv'
config_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\2021-10-19_config.json'
fig_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\3_Graphs'

col_list = ["t_C1_phA_snsr_skin_vert_out",
            "t_C1_phA_cplr_skin_vert_upper",
            "t_C1_phA_cplr_skin_vert_lower",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', ':', '-', '--']
line_color = ['r', 'r', 'r', 'g', 'g']


case1019 = TR.TempRiseExperiment(file_path, config_path)
case1019.find_balance_index(list(range(18, 52)))
case1019.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')

# %% [markdown]
# ## Plot of 20211025

# %%
file_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\20211019_data_clean_10s.csv'
config_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\1_Data formatted\\2021-10-19_config.json'
fig_path = curDirectory + '\\20211019_TR SR40.5kV cable skin vert 630A\\3_Graphs'

# %%
col_list = ["t_C1_phA_snsr_skin_vert_out",
            "t_C1_phA_cplr_skin_vert_upper",
            "t_C1_phA_cplr_skin_vert_lower",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_cplr_bushing"]

line_style = ['-', '--', ':', '-', '--']
line_color = ['r', 'r', 'r', 'g', 'b']


case1019 = TR.TempRiseExperiment(file_path, config_path)
case1019.find_balance_index(list(range(18, 52)))
case1019.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 630A')

# %% [markdown]
# ## Plot of 20211101
# * point 1
# * point 2

# %%
file_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\20211101_data_clean_10s.csv'
config_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\2021-11-01_config.json'
fig_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\3_Graphs'

line_style = ['-', '--', ':', '-', '--']
line_color = ['r', 'r', 'r', 'g', 'g']

case1014 = TR.TempRiseExperiment(file_path, config_path)
case1014.find_balance_index(list(range(18, 52)))

# %%
col_list = ["t_C1_phA_snsr_skin_vert_out",
            "t_C1_phA_skin_vert_out_upper",
            "t_C1_phA_skin_vert_out_low",
            "t_C1_phA_snsr_bushing",
            "t_C1_phA_bushing"]

case1014.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                line_style=line_style,
                line_color=line_color,
                title='Skin TR sensor test Phase A @ 300A')

# %% [markdown]
# ## Plot of 20211104

# %%
file_path = curDirectory + '\\20211104_DTR&TR_3in1_SR12kV 300A\\1_Data formatted\\20211104_data_clean_10s.csv'
config_path = curDirectory + '\\20211104_DTR&TR_3in1_SR12kV 300A\\1_Data formatted\\2021-11-04_config.json'
fig_path = curDirectory + '\\20211104_DTR&TR_3in1_SR12kV 300A\\3_Graphs'

line_style = ['-', '--', ':', '-', '--', ':']
line_color = ['r', 'r', 'r', 'g', 'g', 'g']

case = TR.TempRiseExperiment(file_path, config_path)
case.find_balance_index(list(range(18, 52)))

# %%
col_list = ["t_C1_phA_snsr_bushing",
            "t_C1_phB_snsr_bushing",
            "t_C1_phC_snsr_bushing",
            "t_V3_phA_snsr_skin_vert_out",
            "t_V3_phB_snsr_skin_vert_out",
            "t_V3_phC_snsr_skin_vert_out"] 

for i in col_list:
    case.data[i] = case.np_move_avg(case.data[i], 20, mode='valid')

case.t_plot(col_name_list=col_list,
                fig_path=fig_path,
                # line_style=line_style,
                line_color=line_color,
                title='3in1 sensor test @ 300A')

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211029 of Unit C1 phA

# %%
file_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\20211029_data_clean_10s.csv'
config_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\2021-10-29_config.json'
fig_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\3_Graphs'

case1029_C1A = TR.TempRiseExperiment(file_path, config_path)
case1029_C1A.find_balance_index(list(range(18, 52)))
case1029_C1A.cal_dynamic_time_const('t_C1_phA_snsr_bushing')
# Out:
# Temperature balance time is 2021-10-29 13:26:10.
# time constant T is 5555.1335678170235
# 5555.1335678170235

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211029 of Unit C1 phB

# %%
file_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\20211029_data_clean_10s.csv'
config_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\2021-10-29_config.json'
fig_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\3_Graphs'

case1029_C1B = TR.TempRiseExperiment(file_path, config_path)
case1029_C1B.find_balance_index(list(range(18, 52)))
case1029_C1B.cal_dynamic_time_const('t_C1_phB_snsr_bushing')

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211029 of Unit C1 phC

# %%
file_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\20211029_data_clean_10s.csv'
config_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\1_Data formatted\\2021-10-29_config.json'
fig_path = curDirectory + '\\20211029_DTR&TR_SR12kV 100A\\3_Graphs'

case1029_C1C = TR.TempRiseExperiment(file_path, config_path)
case1029_C1C.find_balance_index(list(range(18, 52)))
case1029_C1C.cal_dynamic_time_const('t_C1_phC_snsr_bushing')

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211101 of Unit C1 phA

# %%
file_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\20211101_data_clean_10s.csv'
config_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\2021-11-01_config.json'
fig_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\3_Graphs'

case1101_C1A = TR.TempRiseExperiment(file_path, config_path)
case1101_C1A.find_balance_index(list(range(18, 52)))
case1101_C1A.cal_dynamic_time_const('t_C1_phA_snsr_bushing')
# Out:
# Temperature balance time is 2021-11-01 14:14:10.
# time constant T is 6526.488150055641
# 6526.488150055641

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211101 of Unit C1 phB

# %%
file_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\20211101_data_clean_10s.csv'
config_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\2021-11-01_config.json'
fig_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\3_Graphs'

case1101_C1B = TR.TempRiseExperiment(file_path, config_path)
case1101_C1B.find_balance_index(list(range(18, 52)))
case1101_C1B.cal_dynamic_time_const('t_C1_phB_snsr_bushing')

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211101 of Unit C1 phC

# %%
file_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\20211101_data_clean_10s.csv'
config_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\1_Data formatted\\2021-11-01_config.json'
fig_path = curDirectory + '\\20211101_DTR&TR_SR12kV 300A\\3_Graphs'

case1101_C1C = TR.TempRiseExperiment(file_path, config_path)
case1101_C1C.find_balance_index(list(range(18, 52)))
case1101_C1C.cal_dynamic_time_const('t_C1_phC_snsr_bushing')

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211105 of Unit C1 phA

# %%
file_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\20211105_data_clean_10s.csv'
config_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\2021-11-05_config.json'
fig_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\3_Graphs'

case1105_C1A = TR.TempRiseExperiment(file_path, config_path)
case1105_C1A.find_balance_index(list(range(18, 52)))
case1105_C1A.cal_dynamic_time_const('t_C1_phA_snsr_bushing')
# Out:
# Temperature balance time is 2021-11-05 18:27:00.
# time constant T is 6684.800557548545
# 6684.800557548545

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211105 of Unit C1 phB

# %%
file_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\20211105_data_clean_10s.csv'
config_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\2021-11-05_config.json'
fig_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\3_Graphs'

case1105_C1B = TR.TempRiseExperiment(file_path, config_path)
case1105_C1B.find_balance_index(list(range(18, 52)))
case1105_C1B.cal_dynamic_time_const('t_C1_phB_snsr_bushing')

# %% [markdown]
# ## Calculation DTR time constant T of test date 20211105 of Unit C1 phC

# %%
file_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\20211105_data_clean_10s.csv'
config_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\1_Data formatted\\2021-11-05_config.json'
fig_path = curDirectory + '\\20211105_DTR&TR_SR12kV 630A\\3_Graphs'

case1105_C1C = TR.TempRiseExperiment(file_path, config_path)
case1105_C1C.find_balance_index(list(range(18, 52)))
case1105_C1C.cal_dynamic_time_const('t_C1_phC_snsr_bushing')

# %% [markdown]
# ## Calculate DTR conversion constant a of test dates on 20211029,20211101,20211105

# %%
tr_100A = case1029_C1A.data.loc[case1029_C1A.bal_idx,'t_C1_phA_snsr_bushing'] - case1029_C1A.t_oil.iloc[case1029_C1A.bal_idx]
tr_300A = case1101_C1A.data.loc[case1101_C1A.bal_idx,'t_C1_phA_snsr_bushing'] - case1101_C1A.t_oil.iloc[case1101_C1A.bal_idx]
tr_630A = case1105_C1A.data.loc[case1105_C1A.bal_idx,'t_C1_phA_snsr_bushing'] - case1105_C1A.t_oil.iloc[case1105_C1A.bal_idx]

conver_const = TR.TempRiseExperiment.cal_dynamic_conver_const([100,300,630],[tr_100A,tr_300A,tr_630A])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18060/447353102.py in <module>
#       3 tr_630A = case1105_C1A.data.loc[case1105_C1A.bal_idx,'t_C1_phA_snsr_bushing'] - case1105_C1A.t_oil.iloc[case1105_C1A.bal_idx]
#       4
# ----> 5 conver_const = TR.TempRiseExperiment.cal_dynamic_conver_const(tr_630A,[100,300],[tr_100A,tr_300A])
#
# TypeError: cal_dynamic_conver_const() takes 2 positional arguments but 3 were given
