# %% [markdown]
# # Initialization

# %%
from safedigital import mechanical as ME  # import mechanical module
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# from MRC.sswgmm_mech import mech_monitor as mm
os.chdir('../') # change working path to one level up
os.chdir('../')
cur_dir = os.getcwd() # get current working path
print(cur_dir)
# Out:
# c:\Users\cnbofan1\ABB\Safe Digital in CN - Documents - Documents\06_Test and Analytics

# %% [markdown]
# # 20221010
# 0-53 cyc

# %%
# generate data path
test_date = '20221010'  # test date 
device_id = '_ME_SA12kV_VVV_SGCC_Life_Test_220VDC_0_53' # test name
test_folder = test_date + device_id  # Test folder
folder_data_raw = cur_dir + '\\' + test_folder + '\\' + '0_Data original'  # raw data folder

# plot angle curves
file_name_angcl = u'角度(合闸).txt'  # file name
file_path_angcl = folder_data_raw + '\\' + file_name_angcl
file_name_angop = u'角度(分闸).txt'  # file name
file_path_angop = folder_data_raw + '\\' + file_name_angop
ME.DataClean.plot_travel_mconfig(file_path_angcl)
ME.DataClean.plot_travel_mconfig(file_path_angop)

# plot current curves
file_name_curop= u'分闸电流(分闸).txt'  # file name
file_path_curop = folder_data_raw + '\\' + file_name_curop
ME.DataClean.plot_travel_mconfig(file_path_curop)
file_name_curcl= u'合闸电流(合闸).txt'  # file name
file_path_curcl = folder_data_raw + '\\' + file_name_curcl
ME.DataClean.plot_travel_mconfig(file_path_curcl)

# plot motor current curves
file_name_curmotor= u'储能电流(储能).txt'  # file name
file_path_curmotor = folder_data_raw + '\\' + file_name_curmotor
ME.DataClean.plot_travel_mconfig(file_path_curmotor)

# %% [markdown]
# # 20221013

# %%
# generate data path
test_date = '20221013'  # test date 
device_id = '_ME_SA12kV_VVV_SGCC_Life_Test_220VDC_1021_1500' # test name
test_folder = test_date + device_id  # Test folder
folder_data_raw = cur_dir + '\\' + test_folder + '\\' + '0_Data original'  # raw data folder

# plot angle curves
file_name_angcl = u'角度(合闸).txt'  # file name
file_path_angcl = folder_data_raw + '\\' + file_name_angcl
file_name_angop = u'角度(分闸).txt'  # file name
file_path_angop = folder_data_raw + '\\' + file_name_angop
ME.DataClean.plot_travel_mconfig(file_path_angcl)
ME.DataClean.plot_travel_mconfig(file_path_angop)

# plot current curves
file_name_curop= u'分闸电流(分闸).txt'  # file name
file_path_curop = folder_data_raw + '\\' + file_name_curop
ME.DataClean.plot_travel_mconfig(file_path_curop)
file_name_curcl= u'合闸电流(合闸).txt'  # file name
file_path_curcl = folder_data_raw + '\\' + file_name_curcl
ME.DataClean.plot_travel_mconfig(file_path_curcl)

# plot motor current curves
file_name_curmotor= u'储能电流(储能).txt'  # file name
file_path_curmotor = folder_data_raw + '\\' + file_name_curmotor
ME.DataClean.plot_travel_mconfig(file_path_curmotor)

# %% [markdown]
# # 20221014

# %%
test_date = '20221014'  # test date 
device_id = '_ME_SA12kV_VVV_SGCC_Life_Test_220VDC_1500_1810' # test name
test_folder = test_date + device_id  # Test folder
folder_data_raw = cur_dir + '\\' + test_folder + '\\' + '0_Data original'  # raw data folder

# plot angle curves
file_name_angcl = u'角度(合闸).txt'  # file name
file_path_angcl = folder_data_raw + '\\' + file_name_angcl
file_name_angop = u'角度(分闸).txt'  # file name
file_path_angop = folder_data_raw + '\\' + file_name_angop
ME.DataClean.plot_travel_mconfig(file_path_angcl)
ME.DataClean.plot_travel_mconfig(file_path_angop)

# plot current curves
file_name_curop= u'分闸电流(分闸).txt'  # file name
file_path_curop = folder_data_raw + '\\' + file_name_curop
ME.DataClean.plot_travel_mconfig(file_path_curop)
file_name_curcl= u'合闸电流(合闸).txt'  # file name
file_path_curcl = folder_data_raw + '\\' + file_name_curcl
ME.DataClean.plot_travel_mconfig(file_path_curcl)

# plot motor current curves
file_name_curmotor= u'储能电流(储能).txt'  # file name
file_path_curmotor = folder_data_raw + '\\' + file_name_curmotor
ME.DataClean.plot_travel_mconfig(file_path_curmotor)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 20221017

# %%
# generate data path
test_date = '20221017'  # test date 
device_id = '_ME_SA12kV_VVV_SGCC_Life_Test_220VDC_1810_2000' # test name
test_folder = test_date + device_id  # Test folder
folder_data_raw = cur_dir + '\\' + test_folder + '\\' + '0_Data original'  # raw data folder

# plot angle curves
file_name_angcl = u'角度(合闸).txt'  # file name
file_path_angcl = folder_data_raw + '\\' + file_name_angcl
file_name_angop = u'角度(分闸).txt'  # file name
file_path_angop = folder_data_raw + '\\' + file_name_angop
ME.DataClean.plot_travel_mconfig(file_path_angcl)
ME.DataClean.plot_travel_mconfig(file_path_angop)

# plot current curves
file_name_curop= u'分闸电流(分闸).txt'  # file name
file_path_curop = folder_data_raw + '\\' + file_name_curop
ME.DataClean.plot_travel_mconfig(file_path_curop)
file_name_curcl= u'合闸电流(合闸).txt'  # file name
file_path_curcl = folder_data_raw + '\\' + file_name_curcl
ME.DataClean.plot_travel_mconfig(file_path_curcl)

# plot motor current curves
file_name_curmotor= u'储能电流(储能).txt'  # file name
file_path_curmotor = folder_data_raw + '\\' + file_name_curmotor
ME.DataClean.plot_travel_mconfig(file_path_curmotor)
